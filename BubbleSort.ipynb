# %%
import random
import time
import matplotlib.pyplot as plt
import seaborn as sns
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
sizes = []
times = []
for size in range(100, 1100, 100):
    arr = [random.randint(1, 1000) for i in range(size)]
    start = time.perf_counter()
    bubble_sort(arr)
    end = time.perf_counter()
    sizes.append(size)
    times.append(end - start)
    print(f"Array Size = {size}, Time = {end-start:.6f} seconds")
sns.set_style("whitegrid")
plt.figure(figsize=(8,5))
sns.lineplot(x=sizes, y=times, marker="o")
plt.title("Bubble Sort Time Complexity")
plt.xlabel("Array Size")
plt.ylabel("Time Taken (seconds)")
plt.show()
# Out:
# Array Size = 100, Time = 0.000848 seconds
# Array Size = 200, Time = 0.003384 seconds
# Array Size = 300, Time = 0.007501 seconds
# Array Size = 400, Time = 0.016721 seconds
# Array Size = 500, Time = 0.025637 seconds
# Array Size = 600, Time = 0.041652 seconds
# Array Size = 700, Time = 0.058416 seconds
# Array Size = 800, Time = 0.077101 seconds
# Array Size = 900, Time = 0.099158 seconds
# Array Size = 1000, Time = 0.122839 seconds
